# %%
# kaggle training code for robosuite environment to bypass python compatibility issues
# micromamba python 3.10

# %%
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# !./bin/micromamba create -y -p /kaggle/working/py310 python=3.10

# %%
# !./bin/micromamba run -p /kaggle/working/py310 pip install \
gymnasium==1.2.3 \
h5py==3.15.1 \
stable_baselines3==2.7.1 \
tensorboard==2.20.0 \
torch==2.10.0 \
tqdm==4.67.3 \
robosuite==1.5.2

# %%
# import py training file as a dataset in kaggle
# !MPLBACKEND=Agg ./bin/micromamba run -p /kaggle/working/py310 python file_path #/kaggle/input/datasets/name/lift-05/lift.py
# !./bin/micromamba run -p /kaggle/working/py310 python file_path #/kaggle/input/datasets/name/lift-05/lift.py
